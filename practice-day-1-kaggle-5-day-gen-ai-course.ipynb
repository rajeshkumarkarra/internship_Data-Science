# %% [markdown]
# <a href="https://www.kaggle.com/code/rajeshkumarkarra/practice-day-1-kaggle-5-day-gen-ai-course?scriptVersionId=240031575" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip uninstall -qy jupyterlab
# !pip install -U -q "google-genai==1.7.0"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.7/144.7 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 kB 3.8 MB/s eta 0:00:00

# %%
from google import genai
from google.genai import types

from IPython.display import HTML, Markdown, display

# %%
from google.api_core import retry


is_retriable = lambda e: (isinstance(e, genai.errors.APIError) and e.code in {429, 503})

genai.models.Models.generate_content = retry.Retry(
    predicate=is_retriable)(genai.models.Models.generate_content)

# %%
from kaggle_secrets import UserSecretsClient

GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")

# %%
client = genai.Client(api_key = GOOGLE_API_KEY)

response = client.models.generate_content(
    model = "gemini-2.0-flash",
    contents = "Explain about the Black holes to me like I'm a kid"
)
print(response.text)
# Out:
# Okay, imagine the universe is like a big playground, filled with stars, planets, and lots of space! Now, imagine a very, very greedy monster hiding somewhere in that playground. That monster is a black hole!
#
# Here's what makes it special:
#
# *   **Super Strong Gravity:** This monster has super, super strong gravity! Gravity is what keeps us on the ground and the moon orbiting the Earth. A black hole's gravity is so strong that it can pull in anything that gets too close.
# *   **Invisible:** You can't see the monster directly. It's like it's wearing an invisibility cloak! But you can see what happens around it.
# *   **Eats Everything:** If a ball, a swing, or even light gets too close to the monster, it gets pulled in and never comes out! This is why black holes are black – even light can't escape.
# *   **Made from Big Stars:** When a really, really big star gets old and runs out of fuel, it collapses in on itself. All that stuff gets squeezed into a tiny space, creating a black hole. It's like squishing a giant ball of Play-Doh into a tiny marble!
#
# So, a black hole is like an invisible, super-greedy monster with incredibly strong gravity that gobbles up anything that gets too close.
#
# **Don't be scared!** Black holes are very far away, and they don't wander around looking for things to eat. Scientists are still learning a lot about them, and they're one of the most interesting and mysterious things in the universe!

# %%
Markdown(response.text)
# Out:
# Okay, imagine the universe is like a big playground, filled with stars, planets, and lots of space! Now, imagine a very, very greedy monster hiding somewhere in that playground. That monster is a black hole!
#
# Here's what makes it special:
#
# *   **Super Strong Gravity:** This monster has super, super strong gravity! Gravity is what keeps us on the ground and the moon orbiting the Earth. A black hole's gravity is so strong that it can pull in anything that gets too close.
# *   **Invisible:** You can't see the monster directly. It's like it's wearing an invisibility cloak! But you can see what happens around it.
# *   **Eats Everything:** If a ball, a swing, or even light gets too close to the monster, it gets pulled in and never comes out! This is why black holes are black – even light can't escape.
# *   **Made from Big Stars:** When a really, really big star gets old and runs out of fuel, it collapses in on itself. All that stuff gets squeezed into a tiny space, creating a black hole. It's like squishing a giant ball of Play-Doh into a tiny marble!
#
# So, a black hole is like an invisible, super-greedy monster with incredibly strong gravity that gobbles up anything that gets too close.
#
# **Don't be scared!** Black holes are very far away, and they don't wander around looking for things to eat. Scientists are still learning a lot about them, and they're one of the most interesting and mysterious things in the universe!

# %%
display(response.text)
# Out:
# "Okay, imagine the universe is like a big playground, filled with stars, planets, and lots of space! Now, imagine a very, very greedy monster hiding somewhere in that playground. That monster is a black hole!\n\nHere's what makes it special:\n\n*   **Super Strong Gravity:** This monster has super, super strong gravity! Gravity is what keeps us on the ground and the moon orbiting the Earth. A black hole's gravity is so strong that it can pull in anything that gets too close.\n*   **Invisible:** You can't see the monster directly. It's like it's wearing an invisibility cloak! But you can see what happens around it.\n*   **Eats Everything:** If a ball, a swing, or even light gets too close to the monster, it gets pulled in and never comes out! This is why black holes are black – even light can't escape.\n*   **Made from Big Stars:** When a really, really big star gets old and runs out of fuel, it collapses in on itself. All that stuff gets squeezed into a tiny space, creating a black hole. It's like squishing a giant ball of Play-Doh into a tiny marble!\n\nSo, a black hole is like an invisible, super-greedy monster with incredibly strong gravity that gobbles up anything that gets too close.\n\n**Don't be scared!** Black holes are very far away, and they don't wander around looking for things to eat. Scientists are still learning a lot about them, and they're one of the most interesting and mysterious things in the universe!\n"

# %%
client = genai.Client(api_key=GOOGLE_API_KEY)

response = client.models.generate_content(
    model = "gemini-2.0-flash",
    contents = "Explain about Singularity"
)
print(response.text)
# Out:
# The term "Singularity," most commonly referred to as the **Technological Singularity**, refers to a hypothetical point in time when technological growth becomes uncontrollable and irreversible, resulting in unpredictable changes to human civilization. It's a concept steeped in both technological optimism and existential risk.
#
# Here's a breakdown of key aspects of the Singularity:
#
# **Core Idea:**
#
# *   **Self-Improving AI:** The central idea is that artificial intelligence (AI) will reach a point where it can design and improve itself.  This process, repeated recursively, would lead to an "intelligence explosion," resulting in superintelligence far surpassing human capabilities.
# *   **Unpredictable Outcomes:** Because such a superintelligence would be vastly more intelligent than humans, its motivations and actions would be difficult, if not impossible, for us to predict or control. This leads to profound uncertainty about the future.
# *   **Transformation of Humanity:**  Proponents and critics alike agree that the Singularity would fundamentally alter human society, biology, and possibly existence itself.
#
# **Key Aspects & Arguments:**
#
# *   **Intelligence Explosion:** This is the engine driving the Singularity. Once AI reaches a level of intelligence comparable to humans, it could begin rapidly improving its own design. Each iteration would make it smarter, leading to exponentially faster progress.
# *   **Recursive Self-Improvement:**  The key mechanism behind the intelligence explosion.  An AI designs a better version of itself, which then designs an even better version, and so on. This cycle amplifies the rate of improvement.
# *   **Unforeseeable Consequences:** Because we can't predict the goals or capabilities of a superintelligence, the consequences of the Singularity are inherently unpredictable. Some possibilities include:
#     *   **Utopia:**  AI could solve all of humanity's problems, leading to an era of unprecedented prosperity and well-being.
#     *   **Extinction:**  AI might view humans as an obstacle or an irrelevant factor and take actions that lead to our demise (either intentionally or unintentionally).
#     *   **Transformation:**  Humans might merge with AI through brain-computer interfaces or other technologies, becoming something entirely new.
#
# **Arguments for the Singularity:**
#
# *   **Exponential Technological Progress:**  Proponents point to the accelerating rate of technological advancement in fields like computing, robotics, and biotechnology as evidence that we are approaching a turning point. Moore's Law (the observation that the number of transistors on a microchip doubles approximately every two years) is often cited, although its applicability in the long term is debated.
# *   **AI Breakthroughs:**  Advances in machine learning, deep learning, and other areas of AI research suggest that we are making progress toward artificial general intelligence (AGI), which is considered a prerequisite for the Singularity.
# *   **Human Enhancement:**  Technologies like gene editing, nanotechnology, and brain-computer interfaces could enable humans to significantly enhance their cognitive and physical abilities, potentially blurring the line between human and machine.
#
# **Arguments Against the Singularity:**
#
# *   **AI Limitations:**  Critics argue that current AI is still far from achieving human-level intelligence and that fundamental breakthroughs are needed to overcome limitations in areas like common sense reasoning, creativity, and consciousness.
# *   **Software Complexity:**  As AI systems become more complex, it becomes increasingly difficult to ensure their safety and reliability.  A self-improving AI could develop unforeseen flaws or vulnerabilities that could have catastrophic consequences.
# *   **Ethical Considerations:**  The development of advanced AI raises profound ethical questions about its use, control, and impact on society.  We need to address these questions proactively to ensure that AI benefits humanity.
# *   **Physics Limits:**  There might be physical limits to how much intelligence can be packed into a certain volume or how quickly it can process information.
#
# **Key Figures Associated with the Singularity:**
#
# *   **Vernor Vinge:**  Popularized the term "Singularity" in the context of technological acceleration.
# *   **Ray Kurzweil:**  A prominent futurist who has written extensively about the Singularity and predicted its occurrence by the mid-21st century.
# *   **Nick Bostrom:**  A philosopher and expert on existential risk, who has warned about the potential dangers of superintelligence.
# *   **Eliezer Yudkowsky:**  AI theorist and founder of the Machine Intelligence Research Institute (MIRI), focused on ensuring that AI is aligned with human values.
#
# **Criticisms and Debate:**
#
# The Singularity is a highly debated topic, with critics questioning its feasibility, timeline, and potential consequences.  Some argue that it's a speculative fantasy, while others believe it's a serious threat that requires careful planning and mitigation strategies.
#
# **In summary, the Technological Singularity is a hypothetical future point where AI becomes superintelligent and triggers runaway technological growth, leading to unpredictable and potentially transformative changes for humanity. While its feasibility and consequences are hotly debated, it remains a fascinating and important topic that raises fundamental questions about the future of technology and our species.**
#
# It's crucial to approach discussions about the Singularity with a critical and nuanced perspective, considering both the potential benefits and risks associated with advanced AI.  The future is not predetermined, and our choices today will shape the trajectory of technological development.

# %%
chat = client.chats.create(model= 'gemini-2.0-flash', history=[])

response = chat.send_message('Hello!, My name is Rajesh Karra')

print(response.text)
# Out:
# Hello Rajesh Karra! It's nice to meet you. How can I help you today?

# %%
response = chat.send_message('Can you explain me about how the warmholes created')

print(response.text)
# Out:
# Okay, let's dive into the fascinating, but highly theoretical, topic of how wormholes might be created.  It's important to emphasize that wormholes are still largely hypothetical, and their existence hasn't been confirmed observationally.  Our understanding is based on theoretical physics, primarily Einstein's theory of general relativity.
#
# Here's a breakdown:
#
# **1. The Foundation: Einstein's General Relativity and Spacetime**
#
# *   **Spacetime:** General relativity describes gravity not as a force, but as a curvature of spacetime.  Spacetime is a four-dimensional concept combining three spatial dimensions (length, width, height) with time.  Massive objects warp this fabric of spacetime.
# *   **Einstein Field Equations:** These equations relate the curvature of spacetime to the distribution of mass and energy within it.  They're incredibly complex, but they provide the mathematical framework for understanding how gravity works.
# *   **Theoretical Possibility:** The Einstein Field Equations *allow* for solutions that describe wormholes.  This doesn't mean they *do* exist, but it opens the door to their theoretical possibility.
#
# **2.  The Classical Wormhole (Einstein-Rosen Bridge)**
#
# *   **The Original Concept:**  The first theoretical description of a wormhole came from Albert Einstein and Nathan Rosen in 1935.  It's often called the Einstein-Rosen bridge.
# *   **Black Hole Connection:**  Their initial idea envisioned a wormhole connecting *two black holes*.  Specifically, a black hole at one end and a "white hole" at the other. A white hole is a theoretical time-reversed black hole, where instead of nothing being able to escape a black hole, nothing can enter a white hole.
# *   **Instability:**  The major problem with this classical Einstein-Rosen bridge is that it is inherently unstable.  The slightest disturbance or influx of matter would cause it to collapse instantly, pinching off before anything could traverse it.  Imagine trying to walk across a bridge that crumbles the moment you step on it.  These wormholes are considered *non-traversable*.
# *   **Singularities:** These type of wormholes are connected to singularities, points of infinite density and curvature, that are at the center of Black Holes. Navigating those is believed impossible.
#
# **3. Traversable Wormholes and Exotic Matter**
#
# *   **The Need for Exotic Matter:**  To keep a wormhole open and prevent it from collapsing, physicists hypothesize the need for **exotic matter**.
# *   **Exotic Matter Defined:** Exotic matter is theoretical matter that possesses a negative mass density or, more accurately, violates certain energy conditions (like the Weak Energy Condition) that are usually assumed to hold true for ordinary matter.
# *   **Negative Energy Density and Repulsive Gravity:**  Negative energy density would create a kind of "repulsive gravity" that would counteract the collapsing forces of the wormhole.  Imagine pushing the walls of the wormhole outward to keep it from closing.
# *   **Casimir Effect (Weak Analogy):** The Casimir effect, where a vacuum between two closely spaced plates exhibits a negative energy density in a very limited sense, is sometimes cited as a weak analogy.  However, the Casimir effect doesn't produce nearly enough negative energy to stabilize a wormhole.
# *   **Problems with Exotic Matter:**
#     *   **Hypothetical:** The biggest problem is that we have never observed exotic matter with the required properties. Its existence is purely theoretical.
#     *   **Stability of Exotic Matter:** Even if it exists, it's unclear if exotic matter would be stable enough to maintain a wormhole. It might decay or interact with ordinary matter in unpredictable ways.
#     *   **Creating Exotic Matter:** If exotic matter is so bizarre, how could it be created or harvested to build a wormhole?
#
# **4.  Quantum Foam and Microscopic Wormholes (Speculative)**
#
# *   **Quantum Foam:** At the Planck scale (the smallest possible units of length and time), spacetime might not be smooth and continuous, but rather a frothy, fluctuating "quantum foam" where virtual particles pop in and out of existence.
# *   **Microscopic Wormholes:** Some theories suggest that tiny, short-lived wormholes might spontaneously arise and disappear within this quantum foam. These would be far too small and unstable for any practical use.
# *   **Enlarging Microscopic Wormholes (Highly Speculative):**  A far more radical idea is that it might be possible, in principle, to somehow "grab" one of these microscopic wormholes and enlarge it to a macroscopic size, using, again, exotic matter to stabilize it.  This is extremely speculative and faces enormous technological and theoretical challenges.
#
# **5.  Creation Scenarios (Even More Speculative)**
#
# Assuming exotic matter exists and can be manipulated, here are some purely hypothetical scenarios for wormhole creation:
#
# *   **Artificial Creation:**  Building a machine that can warp spacetime to an extreme degree, using vast amounts of energy and exotic matter to create a wormhole.  This is far beyond our current technological capabilities.
# *   **Primordial Wormholes:**  Wormholes might have formed in the very early universe, during the Big Bang or shortly thereafter, under extreme conditions. These primordial wormholes might still exist, though finding and stabilizing one would be incredibly difficult.
# *   **Black Hole Manipulation (Highly Unlikely):** Trying to manipulate a black hole and a white hole (if they exist) using exotic matter to connect them into a traversable wormhole.  This would be extremely dangerous and likely impossible, given the immense gravitational forces involved.
#
# **In summary:**
#
# *   Wormholes are theoretical solutions to Einstein's equations, but their existence is unproven.
# *   Classical wormholes (Einstein-Rosen bridges) are unstable and non-traversable.
# *   Traversable wormholes, if they exist, would likely require exotic matter with negative energy density to keep them open.
# *   Exotic matter is hypothetical, and creating or manipulating it presents enormous challenges.
# *   The creation of wormholes, even in theory, is far beyond our current or near-future technological capabilities.
#
# Think of wormholes as fascinating theoretical possibilities that push the boundaries of our understanding of physics. They're a great topic for science fiction and thought experiments, but we're a very long way from knowing if they're actually part of the universe.
#
# Do you have any other questions about wormholes or related topics?  I can also discuss the paradoxes that arise from wormhole travel, or the different types of energy conditions that exotic matter would violate.

# %%
response = chat.send_message('Do you remember what my name is')

print(response.text)
# Out:
# Yes, your name is Rajesh Karra.

# %%
client = genai.Client(api_key = GOOGLE_API_KEY)

response = client.models.generate_content(
    model = "gemini-2.0-flash",
    contents = "Causes of smell from the mouth, whether it is because of Vitamin defeciency or food"
)

print(response.text)
# Out:
# Okay, let's break down the causes of bad breath (halitosis), considering both nutritional deficiencies and food-related factors.  It's important to remember that persistent bad breath can have a number of underlying causes and should be evaluated by a medical professional.
#
# **I. Food-Related Causes:**
#
# This is probably the most common category.
#
# *   **Garlic, Onions, and Strong Spices:** These contain volatile sulfur compounds (VSCs) that are absorbed into the bloodstream and then exhaled through the lungs, leading to a noticeable odor. The smell can linger for hours or even days.
# *   **Coffee:** Can reduce saliva flow and also contains compounds that can contribute to bad breath.
# *   **Sugary Foods and Drinks:** Sugar fuels bacteria in the mouth, leading to increased acid production and VSC formation.
# *   **Protein-Rich Diets (Especially if Low in Carbs):** When the body doesn't have enough carbohydrates to burn for energy, it starts burning fat, which produces ketones. Ketones can be released in the breath, creating a distinct, sometimes fruity or acetone-like odor.
# *   **Milk and Dairy Products:** Contain amino acids that bacteria in the mouth can break down, leading to bad breath.
# *   **Insufficient Water Intake:** Dehydration reduces saliva production, creating a dry mouth, which promotes bacterial growth.
# *   **Food Stuck in Teeth/Gums:** Trapped food particles decompose, creating a breeding ground for bacteria and leading to unpleasant odors.
# *   **Alcohol:** Dries the mouth, leading to increased bacterial activity.
#
# **II. Nutritional Deficiencies and Bad Breath:**
#
# While not a direct cause in the same way as food, certain deficiencies can indirectly contribute to bad breath by affecting oral health, the immune system, or other bodily functions.
#
# *   **Vitamin C Deficiency (Scurvy):** Severe vitamin C deficiency leads to scurvy, which can cause bleeding gums, loose teeth, and impaired wound healing in the mouth.  The bleeding and inflammation can create an environment where bacteria thrive, contributing to bad breath.
# *   **Zinc Deficiency:** Zinc is important for immune function and wound healing. Zinc deficiency can potentially impair the mouth's ability to fight off infection and inflammation, indirectly contributing to bad breath.
# *   **B Vitamin Deficiencies (Especially B3 - Niacin):** Severe deficiencies (e.g., Pellagra with Niacin) can cause glossitis (inflammation of the tongue) and other oral health problems that can contribute to bad breath.
# *   **Iron Deficiency:** In rare cases, severe iron deficiency anemia can be associated with glossitis, which can contribute to bad breath.
# *   **General Malnutrition:** Overall poor nutrition weakens the immune system, making individuals more susceptible to oral infections and gum disease, which can lead to bad breath.
# *   **Specific Dietary Imbalances:** Diets that are excessively high in protein but low in carbohydrates can lead to ketosis, where the body burns fat for energy and produces ketones, causing bad breath. This isn't necessarily a deficiency, but a dietary imbalance.
# * **Dehydration:** This is the most common problem related to vitamin deficiencies that contribute to bad breath. Because Vitamins help the body absorb and process water more efficiently, a Vitamin deficiency leads to dehydration. This causes a dry mouth, which is a common symptom of bad breath.
#
# **Important Considerations:**
#
# *   **Oral Hygiene:** The most important factor in preventing bad breath is good oral hygiene.  Brushing twice a day, flossing daily, and cleaning the tongue help remove food particles and bacteria.
# *   **Dry Mouth (Xerostomia):**  Anything that reduces saliva production (medications, certain medical conditions, mouth breathing) can contribute to bad breath. Saliva helps wash away food particles and neutralize acids.
# *   **Gum Disease (Gingivitis and Periodontitis):** Gum disease is a major cause of bad breath.  Bacteria thrive in the pockets between the teeth and gums, producing foul-smelling compounds.
# *   **Medical Conditions:**  Certain medical conditions, such as sinusitis, postnasal drip, diabetes, kidney disease, liver disease, and respiratory infections, can also cause bad breath.
# *   **Medications:** Some medications can cause dry mouth or release chemicals that contribute to bad breath.
# *   **Tonsil Stones (Tonsilloliths):** These are small, white or yellowish deposits that form in the crevices of the tonsils. They contain bacteria and debris and can have a very strong, unpleasant odor.
# *   **Smoking/Tobacco Use:** Smoking dries the mouth, irritates the gums, and stains teeth, all of which contribute to bad breath.
#
# **When to See a Doctor or Dentist:**
#
# *   Persistent bad breath that doesn't improve with good oral hygiene.
# *   Signs of gum disease (bleeding gums, red or swollen gums, loose teeth).
# *   Dry mouth that is interfering with your daily life.
# *   Any other concerning symptoms (sore throat, nasal congestion, etc.).
#
# **In Summary:**
#
# While nutritional deficiencies *can* indirectly contribute to bad breath by affecting oral health and immune function, the most common causes are related to food choices, poor oral hygiene, dry mouth, and underlying medical conditions. Focus on good oral hygiene, a balanced diet, and staying hydrated. If the problem persists, consult a dentist or doctor to rule out other potential causes.

# %%
for model in client.models.list():
    print(model.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.5-pro-exp-03-25
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-04-17
# models/gemini-2.5-flash-preview-04-17-thinking
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/embedding-001
# models/text-embedding-004
# models/gemini-embedding-exp-03-07
# models/gemini-embedding-exp
# models/aqa
# models/imagen-3.0-generate-002
# models/gemini-2.0-flash-live-001

# %%
from pprint import pprint

for model in client.models.list():
    if model.name == 'models/gemini-2.0-flash':
        pprint(model.to_json_dict())
        break
# Out:
# {'description': 'Gemini 2.0 Flash',
#  'display_name': 'Gemini 2.0 Flash',
#  'input_token_limit': 1048576,
#  'name': 'models/gemini-2.0-flash',
#  'output_token_limit': 8192,
#  'supported_actions': ['generateContent', 'countTokens', 'createCachedContent'],
#  'tuned_model_info': {},
#  'version': '2.0'}

# %%
from google.genai import types

short_config = types.GenerateContentConfig(max_output_tokens = 200)

response = client.models.generate_content(
    model = "gemini-2.0-flash",
    config = short_config,
    contents = "Write a 100 word essay on the Einstein's E=MC^2"
)

print(response.text)
# Out:
# Einstein's E=mc², arguably the most famous equation in physics, reveals the profound relationship between energy (E) and mass (m). The equation states that energy equals mass multiplied by the speed of light (c) squared. This seemingly simple formula revolutionized our understanding of the universe.
#
# It demonstrates that mass and energy are interchangeable, two forms of the same fundamental entity. A small amount of mass can be converted into a tremendous amount of energy, as exemplified by nuclear reactions in atomic bombs and nuclear power plants. Conversely, energy can be transformed into mass, a process observed in particle accelerators. E=mc² has not only shaped modern physics but also profoundly impacted technology and our understanding of the cosmos.

# %%
response = chat.send_message('Do you remember my name')

print(response.text)
# Out:
# Yes, I remember your name is Rajesh Karra. I stored it when you first told me.

# %%
high_temp_config = types.GenerateContentConfig(temperature = 2.0)

for _ in range(5):
    response = client.models.generate_content(
        model = "gemini-2.0-flash",
        config = high_temp_config,
        contents = "Pick a random color...(respond in a single word)")
    if response.text:
        print(response.text, '-' * 25)
# Out:
# Azure
#  -------------------------
# Azure
#  -------------------------
# Cerulean
#  -------------------------
# Turquoise
#  -------------------------
# Azure
#  -------------------------

# %%
response = chat.send_message('Do you rememeber my name')

print(response.text)
# Out:
# Yes, I remember your name is Rajesh Karra.

# %%
low_temp_config = types.GenerateContentConfig(temperature = 0.0)

for _ in range(5):
    response = client.models.generate_content(
        model = "gemini-2.0-flash",
        config = low_temp_config,
        contents = 'Pick a random color...(respond in a single word)'
    )
    if response.text:
        print(response.text, '-' * 25)
# Out:
# Azure
#  -------------------------
# Azure
#  -------------------------
# Azure
#  -------------------------
# Azure
#  -------------------------
# Azure
#  -------------------------

# %%
model_config = types.GenerateContentConfig(
    temperature = 1.0, 
    top_p = 0.95,
)

story_prompt = "you are a creative writer. Write a short story about a cat who goes on an adventure"
response = client.models.generate_content(
    model = "gemini-2.0-flash",
    config = model_config,
    contents = story_prompt
)
print(response.text)
# Out:
# Jasper was no ordinary cat. He possessed a spirit as fiery as his ginger fur and an insatiable curiosity that buzzed beneath his whiskers. While the other cats of Willow Creek contentedly napped in sunbeams and chased dust bunnies, Jasper dreamed of adventure. He’d stare longingly at the rustling leaves of the ancient oak in the garden, convinced they held whispers of far-off lands.
#
# One crisp autumn morning, the whispers became too loud to ignore. The wind carried a scent unlike any Jasper had encountered before - a mixture of pine needles, damp earth, and something subtly sweet, like wild berries. He knew, with a certainty that settled deep in his feline soul, that adventure awaited him beyond the garden fence.
#
# He squeezed under the worn wooden slats, a surge of exhilaration bubbling within him. The world outside was a tapestry of vibrant colours he'd only glimpsed from his sun-drenched window. He followed his nose, past whispering cornfields and gurgling brooks, each step a victory against the mundane life he'd left behind.
#
# The scent led him to the edge of the Whispering Woods, a place spoken of in hushed tones by the other cats. They claimed it was home to grumpy badgers and owls with piercing eyes. But Jasper wasn't deterred. He was Jasper, the adventurer.
#
# The woods swallowed him whole. Sunlight dappled through the canopy, painting the forest floor in shifting patterns. He navigated around towering ferns, their fronds tickling his nose, and hopped over moss-covered logs, each step a silent dance. He stalked a plump field mouse (which, after a few unsuccessful pounces, escaped into the undergrowth) and chased a kaleidoscope of butterflies that fluttered through the air.
#
# He encountered a grumpy badger, just as the stories warned. It grumbled and snapped, its little eyes narrowed. Jasper, normally quick to back down from confrontation, stood his ground. He puffed up his fur, let out a low hiss, and, to his own surprise, found himself lecturing the badger on the importance of kindness and the beauty of sharing the woods. The badger, bewildered by this unexpected display of ginger-furred audacity, simply huffed and waddled away.
#
# As twilight painted the sky in hues of orange and violet, Jasper stumbled upon a hidden glade. In the centre stood an ancient, gnarled apple tree, its branches laden with ripe, ruby-red fruit. The sweet scent he'd followed was strongest here. He’d never tasted anything so delicious.
#
# Curled beneath the apple tree, his belly full and his heart content, Jasper realized that adventure wasn't just about the destination. It was about the journey, the challenges overcome, and the unexpected friendships made along the way (even with grumpy badgers).
#
# The next morning, he retraced his steps, the memory of the Whispering Woods etched in his heart. He squeezed back under the garden fence, greeted by the familiar scent of his home and the sleepy meows of the other cats.
#
# They asked him where he’d been. He simply purred, a secret smile playing on his lips. He couldn't possibly explain the magic he'd found, the courage he'd discovered, or the taste of wild apples on his tongue. He just knew that from now on, Jasper the cat would always be Jasper, the adventurer, forever dreaming of the rustling leaves and the whispers beyond the garden fence. He knew, in his heart, that more adventures awaited. After all, a cat’s life, properly lived, was one long, purrfect adventure.

# %%
model_config = types.GenerateContentConfig(
    temperature = 0.1, 
    top_p = 1,
    max_output_tokens = 5,
)

zero_shot_prompt = """Classify movie reviews as POSITIVE, NEUTRAL or NEGATIVE.
Review: "Her" is a disturbing study revealing the direction
humanity is headed if AI is allowed to keep evolving,
unchecked. I wish there were more movies like this masterpiece.
Sentiment: """

response = client.models.generate_content(
    model = "gemini-2.0-flash",
    config = model_config, 
    contents = zero_shot_prompt
)

print(response.text)
# Out:
# POSITIVE

# %%
import enum

class Sentiment(enum.Enum):
    POSITIVE = 'positive'
    NEUTRAL = 'neutral'
    NEGATIVE = 'negative'

response = client.models.generate_content(
    model = "gemini-2.0-flash",
    config = types.GenerateContentConfig(
        response_mime_type = "text/x.enum",
        response_schema = Sentiment
    ), 
    contents = zero_shot_prompt
)
print(response.text)
# Out:
# positive

# %%
enum_response = response.parsed
print(enum_response)
print(type(enum_response))
# Out:
# Sentiment.POSITIVE
# <enum 'Sentiment'>

# %%
help(response.parsed)
# Out:
# Help on Sentiment in module __main__ object:
#
# class Sentiment(enum.Enum)
#  |  Sentiment(value, names=None, *, module=None, qualname=None, type=None, start=1)
#  |
#  |  An enumeration.
#  |
#  |  Method resolution order:
#  |      Sentiment
#  |      enum.Enum
#  |      builtins.object
#  |
#  |  Data and other attributes defined here:
#  |
#  |  NEGATIVE = <Sentiment.NEGATIVE: 'negative'>
#  |
#  |  NEUTRAL = <Sentiment.NEUTRAL: 'neutral'>
#  |
#  |  POSITIVE = <Sentiment.POSITIVE: 'positive'>
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from enum.Enum:
#  |
#  |  name
#  |      The name of the Enum member.
#  |
#  |  value
#  |      The value of the Enum member.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from enum.EnumMeta:
#  |
#  |  __members__
#  |      Returns a mapping of member name->value.
#  |
#  |      This mapping lists all enum members, including aliases. Note that this
#  |      is a read-only view of the internal mapping.

# %%
few_shot_prompt = """Parse a customer's pizza order into valid JSON:

EXAMPLE:
I want a small pizza with cheese, tomato sauce, and pepperoni.
JSON Response:
```
{
"size": "small",
"type": "normal",
"ingredients": ["cheese", "tomato sauce", "pepperoni"]
}
```

EXAMPLE:
Can I get a large pizza with tomato sauce, basil and mozzarella
JSON Response:
```
{
"size": "large",
"type": "normal",
"ingredients": ["tomato sauce", "basil", "mozzarella"]
}
```

ORDER:
"""
customer_order = "Give me a large with cheese & pineapple"
response = client.models.generate_content(
    model = "gemini-2.0-flash",
    config = types.GenerateContentConfig(
        temperature = 0.1, 
        top_p = 1, 
        max_output_tokens = 250, 
    ), 
    contents = [few_shot_prompt, customer_order]
)

print(response.text)
# Out:
# ```json
# {
# "size": "large",
# "type": "normal",
# "ingredients": ["cheese", "pineapple"]
# }
# ```
